# %%
import os
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import geopandas as gpd 
from functools import reduce
import pandas as pd

# %%
# windows korean font settings (code may vary based on your OS and available fonts)

import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # Trade Area Analysis

# %% [markdown]
# ### Opening Rate and Closing Rate Data Analysis
# - 발달상권
# - 골목상권
# - 전통시장

# %%
# generate a combined dataframe of opening and closing rates for "발달상권", "골목상권", and "전통시장"

# import data for "발달상권"
baldal_path = "상권분석/상권별/발달상권/연도별생존율/"

bd_ys_2017 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2017_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2018 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2018_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2019 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2019_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2020 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2020_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2021 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2021_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2022 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2022_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2023 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2023_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2024 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2024_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_ys_2025 = pd.read_excel(os.path.join(baldal_path, "연도별 생존율(2025_2분기_전분기_발달상권_업종전체_상권별현황).xlsx"))


#import data for "골목상권"
golmok_path = "상권분석/상권별/골목상권/연도별 생존율/"
gm_ys_2017 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2017_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2018 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2018_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2019 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2019_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2020 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2020_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2021 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2021_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2022 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2022_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2023 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2023_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2024 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2024_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_ys_2025 = pd.read_excel(os.path.join(golmok_path, "연도별 생존율(2025_2분기_전분기_골목상권_업종전체_상권별현황).xlsx"))

# import data for "전통시장"
traditional_path = "상권분석/상권별/전통시장/연도별 생존율/"
jt_ys_2017 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2017_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2018 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2018_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2019 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2019_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2020 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2020_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2021 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2021_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2022 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2022_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2023 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2023_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2024 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2024_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_ys_2025 = pd.read_excel(os.path.join(traditional_path, "연도별 생존율(2025_2분기_전분기_전통시장_업종전체_상권별현황).xlsx"))

jt_ys_2019
# Out:
#         행정구역     시군구코드  2019년2분기 1년 생존율  2019년2분기 3년 생존율  2019년2분기 5년 생존율  \
# 0        경기도        31              NaN             90.4             65.6
# 1        수원시      3101              NaN             80.9             65.7
# 2    수원시 장안구     31011              NaN             76.7             63.3
# 3      북수원시장  31011540              0.0             73.3             60.0
# 4       정자시장  31011570              0.0              0.0              0.0
# ..       ...       ...              ...              ...              ...
# 252      양평군      3158              NaN             92.7             63.6
# 253  양평물맑은시장  31580110              0.0             97.5             70.0
# 254  양수리전통시장  31580330              0.0             83.3             50.0
# 255   양동쌍학시장  31580380              0.0              0.0              0.0
# 256   용문천년시장  31580400              0.0             77.8             44.4
#
#      2019년3분기 1년 생존율  2019년3분기 3년 생존율  2019년3분기 5년 생존율  2019년4분기 1년 생존율  \
# ...

# %%
# list of baldal market area dataframes 
bd_ys_list = [
    bd_ys_2017, bd_ys_2018, bd_ys_2019, bd_ys_2020,
    bd_ys_2021, bd_ys_2022, bd_ys_2023, bd_ys_2024, bd_ys_2025
]

# merge all dataframes on the same keys
bd_ys = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), bd_ys_list)
# add a column that indicates the market area type
bd_ys["상권유형"] = "발달상권"
# filter for "고양시(goyang city)"
bd_ys = bd_ys[bd_ys["행정구역"] == "고양시"]

# list of golmok market area dataframes
gm_ys_list = [
    gm_ys_2017, gm_ys_2018, gm_ys_2019, gm_ys_2020,
    gm_ys_2021, gm_ys_2022, gm_ys_2023, gm_ys_2024, gm_ys_2025
]   
# merge all dataframes on the same keys
gm_ys = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), gm_ys_list)
# add a column that indicates the market area type
gm_ys["상권유형"] = "골목상권"
# filter for "고양시(goyang city)"
gm_ys = gm_ys[gm_ys["행정구역"] == "고양시"]

# list of jeontong market area dataframes
jt_ys_list = [
    jt_ys_2017, jt_ys_2018, jt_ys_2019, jt_ys_2020,
    jt_ys_2021, jt_ys_2022, jt_ys_2023, jt_ys_2024, jt_ys_2025
]
# merge all dataframes on the same keys
jt_ys = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), jt_ys_list) 
# add a column that indicates the market area type
jt_ys["상권유형"] = "전통시장"
# filter for "고양시(goyang city)"
jt_ys = jt_ys[jt_ys["행정구역"] == "고양시"]

# concatenate all market area dataframes into a single dataframe
combined_ys = pd.concat([bd_ys, gm_ys, jt_ys], ignore_index=True)
combined_ys
# Out:
#   행정구역  시군구코드  2017년2분기 1년 생존율  2017년2분기 3년 생존율  2017년2분기 5년 생존율  \
# 0  고양시   3110              NaN             90.0             89.5
# 1  고양시   3110              NaN              NaN             82.4
# 2  고양시   3110              NaN              NaN              NaN
#
#    2017년3분기 1년 생존율  2017년3분기 3년 생존율  2017년3분기 5년 생존율  2017년4분기 1년 생존율  \
# 0              NaN             90.9             87.2              NaN
# 1              NaN              NaN             82.3              NaN
# 2              NaN              NaN             84.6              NaN
#
#    2017년4분기 3년 생존율  ...  2024년4분기 1년 생존율_y  2024년4분기 3년 생존율_y  \
# 0             97.1  ...               84.6               62.4
# 1              NaN  ...               78.7               56.4
# 2              NaN  ...               93.9               68.3
#
#    2024년4분기 5년 생존율_y  2025년1분기 1년 생존율  2025년1분기 3년 생존율  2025년1분기 5년 생존율  \
# 0               47.3             85.2             61.8             47.2
# ...

# %%
# filter 생존율 columns only 
survival_columns = [col for col in combined_ys.columns if "생존율" in col]
filtered_survival_data = combined_ys[["행정구역", "시군구코드", "상권유형"] + survival_columns]

# transverse the columns and rows for better readability
filtered_survival_data = filtered_survival_data.melt(id_vars=["행정구역", "시군구코드", "상권유형"], var_name="연도_분기", value_name="생존율")   

# make a year column and quarter column using the '연도_분기' column
filtered_survival_data[['연도', '분기']] = filtered_survival_data['연도_분기'].str.extract(r'(\d{4})년(\d+분기)')
del filtered_survival_data['연도_분기']

# average 생존율 for each year and market area type 
filtered_survival_data = filtered_survival_data.groupby(['연도', '상권유형']).agg({'생존율': 'mean'}).reset_index()

# extract the values of year 2025
filtered_survival_data = filtered_survival_data[filtered_survival_data['연도'] != '2025']
filtered_survival_data
# Out:
#       연도  상권유형        생존율
# 0   2017  골목상권  81.833333
# 1   2017  발달상권  89.750000
# 2   2017  전통시장  79.800000
# 3   2018  골목상권  69.220000
# 4   2018  발달상권  86.783333
# 5   2018  전통시장  58.566667
# 6   2019  골목상권  73.816667
# 7   2019  발달상권  76.233333
# 8   2019  전통시장  74.380000
# 9   2020  골목상권  61.485714
# 10  2020  발달상권  73.088889
# 11  2020  전통시장  61.750000
# 12  2021  골목상권  58.588889
# 13  2021  발달상권  62.688889
# 14  2021  전통시장  65.644444
# 15  2022  골목상권  58.411111
# 16  2022  발달상권  61.800000
# 17  2022  전통시장  64.575000
# 18  2023  골목상권  63.688889
# 19  2023  발달상권  63.977778
# 20  2023  전통시장  62.333333
# 21  2024  골목상권  60.816667
# 22  2024  발달상권  65.950000
# 23  2024  전통시장  70.966667

# %%
# plot the survival rates for each market area type over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_survival_data, x='연도', y='생존율', hue='상권유형', marker='o')
plt.title('고양시 1년 생존율 추이 (%)')
plt.xlabel('연도')
plt.ylabel('생존율 (%)')
plt.legend(title='상권유형')
plt.show()

# %% [markdown]
# # 업종별 분석

# %%
service_path = "상권분석\지역별(행정동별)\연도별 생존율\서비스업"
service_ys_2017 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2017_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2018 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2018_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2019 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2019_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2020 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2020_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2021 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2021_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2022 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2022_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2023 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2023_4분기_전분기_업종전체_지역별현황).xlsx"))
service_ys_2024 = pd.read_excel(os.path.join(service_path, "연도별 생존율(2024_4분기_전분기_업종전체_지역별현황).xlsx"))


retail_path = "상권분석\지역별(행정동별)\연도별 생존율\소매업"
retail_ys_2017 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2017_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2018 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2018_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2019 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2019_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2020 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2020_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2021 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2021_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2022 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2022_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2023 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2023_4분기_전분기_업종전체_지역별현황).xlsx"))
retail_ys_2024 = pd.read_excel(os.path.join(retail_path, "연도별 생존율(2024_4분기_전분기_업종전체_지역별현황).xlsx"))


food_path = "상권분석\지역별(행정동별)\연도별 생존율\음식업"

food_ys_2017 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2017_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2018 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2018_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2019 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2019_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2020 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2020_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2021 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2021_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2022 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2022_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2023 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2023_4분기_전분기_업종전체_지역별현황).xlsx"))
food_ys_2024 = pd.read_excel(os.path.join(food_path, "연도별 생존율(2024_4분기_전분기_업종전체_지역별현황).xlsx"))

food_ys_2019
# Out:
#         행정구역      지역코드  2019년2분기 1년 생존율  2019년2분기 3년 생존율  2019년2분기 5년 생존율  \
# 0        경기도        31             99.9             90.3             61.7
# 1        수원시     31010              0.0             89.7             61.3
# 2    수원시 장안구     31011              0.0             87.4             56.1
# 3        파장동  31011540              0.0             76.7             46.7
# 4        율천동  31011550              0.0             85.7             57.1
# ..       ...       ...              ...              ...              ...
# 601      청운면  31580370              0.0             60.0             60.0
# 602      양동면  31580380              0.0              0.0              0.0
# 603      지평면  31580390              0.0              0.0             83.3
# 604      용문면  31580400              0.0             85.0             60.0
# 605      개군면  31580410              0.0              0.0              0.0
#
#      2019년3분기 1년 생존율  2019년3분기 3년 생존율  2019년3분기 5년 생존율  2019년4분기 1년 생존율  \
# ...

# %%
# filter duseh 생존율 columns only 
survival_columns = [col for col in combined_nbsr.columns if "5년" in col]
filtered_survival_data = combined_nbsr[["행정구역", "지역코드", "업종"] + survival_columns]

# transverse the columns and rows for better readability
filtered_survival_data = filtered_survival_data.melt(id_vars=["행정구역", "지역코드", "업종"], var_name="연도_분기", value_name="생존율(5년)")   

# make a year column and quarter column using the '연도_분기' column
filtered_survival_data[['연도', '분기']] = filtered_survival_data['연도_분기'].str.extract(r'(\d{4})년(\d+분기)')
del filtered_survival_data['연도_분기']

# average 생존율 for each year and market area type 
filtered_survival_data = filtered_survival_data.groupby(['연도', '업종']).agg({'생존율(5년)': 'mean'}).reset_index()

# extract the values of year 2025
filtered_survival_data = filtered_survival_data[filtered_survival_data['연도'] != '2025']
filtered_survival_data
