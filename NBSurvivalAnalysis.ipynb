# %%
import os
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import geopandas as gpd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # Trade Area Analysis
#
# ### New Business Survival Rate

# %%
# import data 

baldal_path = "상권분석/상권별/발달상권/신생기업생존율/"
golmok_path = "상권분석/상권별/골목상권/신생기업 생존율/"
traditional_path = "상권분석/상권별/전통시장/신생기업 생존율/"

# import data for 발달상권 
bd_nbsr_2017 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2017_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2018 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2018_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2019 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2019_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2020 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2020_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2021 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2021_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2022 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2022_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2023 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2023_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2024 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2024_4분기_전분기_발달상권_업종전체_상권별현황).xlsx"))
bd_nbsr_2025 = pd.read_excel(os.path.join(baldal_path, "신생기업 생존율(2025_2분기_전분기_발달상권_업종전체_상권별현황).xlsx"))

# import data for 골목상권 
gm_nbsr_2017 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2017_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2018 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2018_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2019 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2019_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2020 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2020_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2021 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2021_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2022 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2022_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2023 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2023_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2024 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2024_4분기_전분기_골목상권_업종전체_상권별현황).xlsx"))
gm_nbsr_2025 = pd.read_excel(os.path.join(golmok_path, "신생기업 생존율(2025_2분기_전분기_골목상권_업종전체_상권별현황).xlsx"))

# import data for 전통시장
jt_nbsr_2017 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2017_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2018 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2018_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2019 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2019_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2020 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2020_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2021 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2021_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2022 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2022_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))    
jt_nbsr_2023 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2023_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2024 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2024_4분기_전분기_전통시장_업종전체_상권별현황).xlsx"))
jt_nbsr_2025 = pd.read_excel(os.path.join(traditional_path, "신생기업 생존율(2025_2분기_전분기_전통시장_업종전체_상권별현황).xlsx"))

bd_nbsr_2018
# Out:
#            행정구역     시군구코드  2018년2분기 1년 생존율  2018년2분기 3년 생존율  2018년2분기 5년 생존율  \
# 0           경기도        31             81.5             74.1             79.9
# 1           수원시      3101             82.3             75.0             80.7
# 2       수원시 장안구     31011             80.3             72.9             77.3
# 3    수원정자동우편취급국  31011540             75.7             41.2            100.0
# 4           서부로  31011550             87.2             91.7            100.0
# ..          ...       ...              ...              ...              ...
# 935    양근로147번길  31580110             85.7             75.0             85.7
# 936       양평경찰서  31580110             63.6             76.9             83.3
# 937   양평시외버스정류장  31580110             77.8             83.3             83.3
# 938      양수리정류소  31580330             77.8             50.0             75.0
# 939         용문역  31580400             84.4             76.9             86.7
#
# ...

# %%
# combine dataframes as needed 

from functools import reduce
import pandas as pd

# list of baldal market area dataframes 
bd_nbsr_list = [
    bd_nbsr_2017, bd_nbsr_2018, bd_nbsr_2019, bd_nbsr_2020,
    bd_nbsr_2021, bd_nbsr_2022, bd_nbsr_2023, bd_nbsr_2024, bd_nbsr_2025
]

# merge all dataframes on the same keys
bd_nbsr = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), bd_nbsr_list)
# add a column that indicates the market area type
bd_nbsr["상권유형"] = "발달상권"
# filter for "고양시(goyang city)"
bd_nbsr = bd_nbsr[bd_nbsr["행정구역"] == "고양시"]

# list of golmok market area dataframes
gm_nbsr_list = [
    gm_nbsr_2017, gm_nbsr_2018, gm_nbsr_2019, gm_nbsr_2020,
    gm_nbsr_2021, gm_nbsr_2022, gm_nbsr_2023, gm_nbsr_2024, gm_nbsr_2025
]   
# merge all dataframes on the same keys
gm_nbsr = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), gm_nbsr_list)
# add a column that indicates the market area type
gm_nbsr["상권유형"] = "골목상권"
# filter for "고양시(goyang city)"
gm_nbsr = gm_nbsr[gm_nbsr["행정구역"] == "고양시"]

# list of jeontong market area dataframes
jt_nbsr_list = [
    jt_nbsr_2017, jt_nbsr_2018, jt_nbsr_2019, jt_nbsr_2020,
    jt_nbsr_2021, jt_nbsr_2022, jt_nbsr_2023, jt_nbsr_2024, jt_nbsr_2025
]
# merge all dataframes on the same keys
jt_nbsr = reduce(lambda left, right: pd.merge(left, right, on=["행정구역", "시군구코드"], how="inner"), jt_nbsr_list) 
# add a column that indicates the market area type
jt_nbsr["상권유형"] = "전통시장"
# filter for "고양시(goyang city)"
jt_nbsr = jt_nbsr[jt_nbsr["행정구역"] == "고양시"]

# concatenate all market area dataframes into a single dataframe
combined_nbsr = pd.concat([bd_nbsr, gm_nbsr, jt_nbsr], ignore_index=True)
combined_nbsr
# Out:
#   행정구역  시군구코드  2017년2분기 1년 생존율  2017년2분기 3년 생존율  2017년2분기 5년 생존율  \
# 0  고양시   3110             89.4             92.4             92.1
# 1  고양시   3110             86.3             92.1             91.4
# 2  고양시   3110             90.0             93.3            100.0
#
#    2017년3분기 1년 생존율  2017년3분기 3년 생존율  2017년3분기 5년 생존율  2017년4분기 1년 생존율  \
# 0             85.8             88.5             90.3             83.1
# 1             83.8             87.1             88.4             81.5
# 2             77.3             93.8             84.6             69.6
#
#    2017년4분기 3년 생존율  ...  2024년4분기 1년 생존율_y  2024년4분기 3년 생존율_y  \
# 0             84.6  ...               75.2               51.6
# 1             84.4  ...               71.9               49.0
# 2            100.0  ...               61.5               66.7
#
#    2024년4분기 5년 생존율_y  2025년1분기 1년 생존율  2025년1분기 3년 생존율  2025년1분기 5년 생존율  \
# 0               46.4             76.0             52.0             44.1
# ...

# %%
# filter 생존율 columns only 
survival_columns = [col for col in combined_nbsr.columns if "생존율" in col]
filtered_survival_data = combined_nbsr[["행정구역", "시군구코드", "상권유형"] + survival_columns]

# transverse the columns and rows for better readability
filtered_survival_data = filtered_survival_data.melt(id_vars=["행정구역", "시군구코드", "상권유형"], var_name="연도_분기", value_name="생존율")   

# make a year column and quarter column using the '연도_분기' column
filtered_survival_data[['연도', '분기']] = filtered_survival_data['연도_분기'].str.extract(r'(\d{4})년(\d+분기)')
del filtered_survival_data['연도_분기']

# average 생존율 for each year and market area type 
filtered_survival_data = filtered_survival_data.groupby(['연도', '상권유형']).agg({'생존율': 'mean'}).reset_index()

# extract the values of year 2025
filtered_survival_data = filtered_survival_data[filtered_survival_data['연도'] != '2025']
filtered_survival_data
# Out:
#       연도  상권유형        생존율
# 0   2017  골목상권  86.688889
# 1   2017  발달상권  88.000000
# 2   2017  전통시장  88.922222
# 3   2018  골목상권  72.911111
# 4   2018  발달상권  77.533333
# 5   2018  전통시장  71.433333
# 6   2019  골목상권  67.066667
# 7   2019  발달상권  68.222222
# 8   2019  전통시장  73.811111
# 9   2020  골목상권  60.188889
# 10  2020  발달상권  63.866667
# 11  2020  전통시장  68.177778
# 12  2021  골목상권  57.733333
# 13  2021  발달상권  60.222222
# 14  2021  전통시장  62.966667
# 15  2022  골목상권  56.544444
# 16  2022  발달상권  59.966667
# 17  2022  전통시장  65.022222
# 18  2023  골목상권  58.622222
# 19  2023  발달상권  58.088889
# 20  2023  전통시장  65.877778
# 21  2024  골목상권  54.883333
# 22  2024  발달상권  57.650000
# 23  2024  전통시장  58.741667

# %%
# plot the survival rates for each market area type over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=filtered_survival_data, x='연도', y='생존율', hue='상권유형', marker='o')
plt.title('고양시 연도별 신생기업 생존율 추이 (%)')
plt.xlabel('연도')
plt.ylabel('생존율 (%)')
plt.legend(title='상권유형')
plt.show()
